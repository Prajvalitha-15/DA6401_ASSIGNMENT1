# %%
from keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt
import wandb

# %%
# Initialize WandB
wandb.init(project="assignment1", entity="da6401-assignments")
# Out:
# creating run (0.3s)
# Tracking run with wandb version 0.19.8
# Run data is saved locally in <code>c:\Users\prajv\Downloads\ass1\DA6401_ASSIGNMENT1\wandb\run-20250309_154924-9s41ckaj</code>
# Syncing run <strong><a href='https://wandb.ai/da6401-assignments/assignment1/runs/9s41ckaj' target="_blank">jolly-dawn-2</a></strong> to <a href='https://wandb.ai/da6401-assignments/assignment1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/da6401-assignments/assignment1' target="_blank">https://wandb.ai/da6401-assignments/assignment1</a>
#  View run at <a href='https://wandb.ai/da6401-assignments/assignment1/runs/9s41ckaj' target="_blank">https://wandb.ai/da6401-assignments/assignment1/runs/9s41ckaj</a>
# ...

# %%
# Loading the Fashion-MNIST dataset
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Extracting unique classes
unique_classes = np.unique(y_train)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Get a sample image for each class
sample_images = []
for cls in unique_classes:
    # Find the first occurrence of each class in the training set
    idx = np.where(y_train == cls)[0][0]
    sample_images.append(x_train[idx])

# %%
# Define class labels
class_labels = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
for i, (img, label) in enumerate(zip(sample_images, class_labels)):
    wandb.log({f"Sample Image {i+1}": [wandb.Image(img, caption=label)]})
plt.figure(figsize=(10, 10))
for i, (img, label) in enumerate(zip(sample_images, class_labels)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(img, cmap="gray")
    plt.title(label)
    plt.axis("off")
plt.tight_layout()
plt.show()
wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">jolly-dawn-2</strong> at: <a href='https://wandb.ai/da6401-assignments/assignment1/runs/9s41ckaj' target="_blank">https://wandb.ai/da6401-assignments/assignment1/runs/9s41ckaj</a><br> View project at: <a href='https://wandb.ai/da6401-assignments/assignment1' target="_blank">https://wandb.ai/da6401-assignments/assignment1</a><br>Synced 5 W&B file(s), 10 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250309_154924-9s41ckaj\logs</code>
